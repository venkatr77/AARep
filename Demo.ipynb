# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatr77/AARep/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Enter Number 1:  "))
y = int(input("Enter Number 2:  "))
sum = x+y
mul = x*y
div = x/y
sub = x-y
print("Addition of given number is  :  ",sum)
print("Subtraction of given number is  :  ",sub)
print("Division of given number is  :  ",div)
print("Multiply of given number is  :  ",mul)
# Out:
# Enter Number 1:  4
# Enter Number 2:  6
# Addition of given number is  :   10
# Subtraction of given number is  :   -2
# Division of given number is  :   0.6666666666666666
# Multiply of given number is  :   24

# %% [markdown]
# Write a python program that takes two numbers as input and gives me addition, subtraction, division and multiplication

# %%
x = int(input("Enter Number 1:  "))
y = int(input("Enter Number 2:  "))
sum = x+y
mul = x*y
div = x/y
sub = x-y
print("Addition of given number is  :  ",sum)
print("Subtraction of given number is  :  ",sub)
print("Division of given number is  :  ",div)
print("Multiply of given number is  :  ",mul)
# Out:
# Enter Number 1:  120
# Enter Number 2:  10
# Addition of given number is  :   130
# Subtraction of given number is  :   110
# Division of given number is  :   12.0
# Multiply of given number is  :   1200
